# %%
# STEP-1
# LOAD THE DATA FROM SOURCE..

from pyspark.sql import SparkSession
spark=SparkSession.builder.appName('appmane').getOrCreate()
from pyspark.sql.functions import col, when, count
df1=spark.read.csv('/FileStore/tables/AppleStore1-8.csv',header=True,inferSchema=True)
df1.show()
# Out:
# +--------------------+------------+---------+--------+-----+------------+----------------+----------------+--------------------+-------+---------------+-----------------+------------+----------+---------+-------+
# |            App Name|Size (bytes)|   App id|Currency|Price|Rating (All)|Rating (Current)|Avg Rating (All)|Avy Rating (Current)|Version|Rating(Content)|        Prefrence|Supp Devices|Screenshot|Supp Lang|Vpp Lic|
# +--------------------+------------+---------+--------+-----+------------+----------------+----------------+--------------------+-------+---------------+-----------------+------------+----------+---------+-------+
# |     PAC-MAN Premium|   100788224|281656475|     USD| 3.99|       21292|              26|             4.0|                 4.5|  6.3.5|             4+|            Games|          38|         5|       10|      1|
# ...

# %%
# STEP-2
# # LOAD SECOND DATA FROM SOURCE
df2=spark.read.csv('/FileStore/tables/AppleStore2-6.csv',header=True,inferSchema=True)
df2.show()
# Out:
# +------------------------------------+------------+---------+--------+-----+------------+----------------+----------------+--------------------+-------+---------------+-------------+------------+----------+---------+-------+
# |                            App Name|Size (bytes)|   App id|Currency|Price|Rating (All)|Rating (Current)|Avg Rating (All)|Avy Rating (Current)|Version|Rating(Content)|    Prefrence|Supp Devices|Screenshot|Supp Lang|Vpp Lic|
# +------------------------------------+------------+---------+--------+-----+------------+----------------+----------------+--------------------+-------+---------------+-------------+------------+----------+---------+-------+
# |银联钱包- 银行卡管家，扫码支付享优惠|    91323392|600273928|     USD|  0.0|           9|               1|             3.5|                 3.0|  4.5.3|            17+|      Finance|          37|         0|        1|      1|
# ...

# %%
# STEP-3
# LOAD THIRD DATA FROM SOURCE

df3=spark.read.csv('/FileStore/tables/AppleStore3-3.csv',header=True,inferSchema=True)
df3.show()
# Out:
# +-----------------------+------------+---------+--------+-----+------------+----------------+----------------+--------------------+-------+---------------+-----------------+------------+----------+---------+-------+
# |               App Name|Size (bytes)|   App id|Currency|Price|Rating (All)|Rating (Current)|Avg Rating (All)|Avy Rating (Current)|Version|Rating(Content)|        Prefrence|Supp Devices|Screenshot|Supp Lang|Vpp Lic|
# +-----------------------+------------+---------+--------+-----+------------+----------------+----------------+--------------------+-------+---------------+-----------------+------------+----------+---------+-------+
# |       Thumbly Keyboard|    60309504|978201325|     USD| 1.99|          53|               0|             3.0|                 0.0|  1.2.3|             4+|        Utilities|          37|         0|        1|      1|
# ...

# %%
# STEP-4 
# LOAD FOURTH DATA FROM SOURCE
df4=spark.read.csv('/FileStore/tables/AppleStore4-2.csv',header=True,inferSchema=True)
df4.show()
# Out:
# +--------------------+------------+----------+--------+-----+------------+----------------+----------------+--------------------+-------+---------------+-----------------+------------+----------+---------+-------+
# |            App Name|Size (bytes)|    App id|Currency|Price|Rating (All)|Rating (Current)|Avg Rating (All)|Avy Rating (Current)|Version|Rating(Content)|        Prefrence|Supp Devices|Screenshot|Supp Lang|Vpp Lic|
# +--------------------+------------+----------+--------+-----+------------+----------------+----------------+--------------------+-------+---------------+-----------------+------------+----------+---------+-------+
# |CITB op/spec HS&E...|    24169472|1082673403|     USD| 5.99|           0|               0|             0.0|                 0.0| 3.0.17|            12+|        Education|          37|         5|        1|      1|
# ...

# %%
# STEP-5
# COMBINED ABOVE ALL FOUR DATA SET IN ONE DATA FRAME FOR OPTIMIZZTION.

columns = df1.columns

df2 = df2.select(columns)
df3 = df3.select(columns)
df4 = df4.select(columns)

merged_df = df1.union(df2).union(df3).union(df4)
merged_df.show()
# Out:
# +--------------------+------------+---------+--------+-----+------------+----------------+----------------+--------------------+-------+---------------+-----------------+------------+----------+---------+-------+
# |            App Name|Size (bytes)|   App id|Currency|Price|Rating (All)|Rating (Current)|Avg Rating (All)|Avy Rating (Current)|Version|Rating(Content)|        Prefrence|Supp Devices|Screenshot|Supp Lang|Vpp Lic|
# +--------------------+------------+---------+--------+-----+------------+----------------+----------------+--------------------+-------+---------------+-----------------+------------+----------+---------+-------+
# |     PAC-MAN Premium|   100788224|281656475|     USD| 3.99|       21292|              26|             4.0|                 4.5|  6.3.5|             4+|            Games|          38|         5|       10|      1|
# ...

# %%
# STEP-6 
# MERGED ALL DATA 

merged_df.count()
# Out:
# Out[30]: 7197

# %%
# STEP-7 
# MERGED DATA AND DROP DUPLICATES VALUE IN DATA SET.
df_cleaned = merged_df.dropDuplicates()
merged_df.show()
# Out:
# +--------------------+------------+---------+--------+-----+------------+----------------+----------------+--------------------+-------+---------------+-----------------+------------+----------+---------+-------+
# |            App Name|Size (bytes)|   App id|Currency|Price|Rating (All)|Rating (Current)|Avg Rating (All)|Avy Rating (Current)|Version|Rating(Content)|        Prefrence|Supp Devices|Screenshot|Supp Lang|Vpp Lic|
# +--------------------+------------+---------+--------+-----+------------+----------------+----------------+--------------------+-------+---------------+-----------------+------------+----------+---------+-------+
# |     PAC-MAN Premium|   100788224|281656475|     USD| 3.99|       21292|              26|             4.0|                 4.5|  6.3.5|             4+|            Games|          38|         5|       10|      1|
# ...

# %%
# STEP-8 
# FIND OUT ALL COLUMN NAME 

for col_name in df.columns:
    print(col_name)
# Out:
# App Name
# Size (bytes)
# App id
# Currency
# Price
# Rating (All)
# Rating (Current)
# Avg Rating (All)
# Avy Rating (Current)
# Version
# Rating(Content)
# Prefrence
# Supp Devices
# Screenshot
# Supp Lang
# Vpp Lic

# %%
# STEP-9
# FIND OUT MIXING VALUE IN DATA SET.
for col_name in df.columns:
    null_count=df.filter(col(col_name).isNull()).count()
    print(f"number of null values in column '{col_name}':{null_count}")
# Out:
# number of null values in column 'App Name':0
# number of null values in column 'Size (bytes)':0
# number of null values in column 'App id':0
# number of null values in column 'Currency':0
# number of null values in column 'Price':0
# number of null values in column 'Rating (All)':0
# number of null values in column 'Rating (Current)':0
# number of null values in column 'Avg Rating (All)':0
# number of null values in column 'Avy Rating (Current)':0
# number of null values in column 'Version':0
# number of null values in column 'Rating(Content)':0
# number of null values in column 'Prefrence':0
# number of null values in column 'Supp Devices':0
# number of null values in column 'Screenshot':0
# number of null values in column 'Supp Lang':0
# number of null values in column 'Vpp Lic':0

# %%
# STEP-10 
# THERE IS NO MIXING VALUES AVALIBLE IN DATA SET.

# %%
# STEP-11
# NOW WE HAVE FINAL DATA SET FOR FURTHER ANALYSIS.

FINAL_DATA=merged_df.show()
# Out:
# +--------------------+------------+---------+--------+-----+------------+----------------+----------------+--------------------+-------+---------------+-----------------+------------+----------+---------+-------+
# |            App Name|Size (bytes)|   App id|Currency|Price|Rating (All)|Rating (Current)|Avg Rating (All)|Avy Rating (Current)|Version|Rating(Content)|        Prefrence|Supp Devices|Screenshot|Supp Lang|Vpp Lic|
# +--------------------+------------+---------+--------+-----+------------+----------------+----------------+--------------------+-------+---------------+-----------------+------------+----------+---------+-------+
# |     PAC-MAN Premium|   100788224|281656475|     USD| 3.99|       21292|              26|             4.0|                 4.5|  6.3.5|             4+|            Games|          38|         5|       10|      1|
# ...

# %%
# STEP-12
# SAVE THE FINAL DATA IN CSV FORMAT .
df.write.csv("output.csv", header=True, mode="overwrite")
